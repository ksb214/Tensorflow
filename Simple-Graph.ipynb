# %%
import tensorflow as tf

# %%
a = tf.constant(5)
b = tf.constant(2)
c = tf.constant(3)

# %%
d = tf.multiply(a,b)
e = tf.add(b,c)
f = tf.subtract(d,e)

# %% [markdown]
# Run method completes one set of computations in our graph in the following manner: it starts at the requested output(s) and then works backward, computing nodes that must be executed according to the set of dependencies.
#
# ![image.png](attachment:image.png)

# %%
sess = tf.Session()
outs = sess.run(f)
print ('Output is = {}'.format(outs))
sess.close()
# Out:
# Output is = 5

# %% [markdown]
# Opening a session using the with clause will ensure the session is automatically closed once all computations are done.

# %%
# Using Fetches to get all variables
with tf.Session() as sess:
    fetches = [d, e, f]
    outs = sess.run(fetches)

print ('Output d, e, f are {}'.format(outs))
# Out:
# Output d, e, f are [10, 5, 5]

# %%
print(type(outs[0]))
# Out:
# <class 'numpy.int32'>
